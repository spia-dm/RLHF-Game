# %%
# %pip list

# %%
import pygame
import gymnasium as gym
import random
import numpy as np
from gymnasium import Env, spaces
from typing import Optional

class ParkingEnv(Env):
    metadata = {"render_modes": ["human"], "render_fps": 20}

    def __init__(self, render_mode: Optional[str] = None):
        super(ParkingEnv, self).__init__()
        self.SCREEN_WIDTH = 500
        self.SCREEN_HEIGHT = 500
        self.WHITE = (255, 255, 255)
        self.BLACK = (0, 0, 0)
        self.RED = (255, 0, 0)
        self.GREEN = (0, 255, 0)
        
        self.car_width = 50
        self.car_height = 50
        self.car_speed = 20

        self.action_space = spaces.Discrete(4)  # [left, right, up, down]
        self.observation_space = spaces.Box(
            low=0,
            high=max(self.SCREEN_WIDTH, self.SCREEN_HEIGHT),
            shape=(2,),  # Car's x, y coordinates
            dtype=np.float32
        )
        
        self.render_mode = render_mode
        self.screen = None
        self.clock = None

        self.obstacles = []
        self.destinations = []
        
        self.reset()
        self.times = 0

    def reset(self):
        self.car_x = random.randint(0, self.SCREEN_WIDTH - self.car_width)
        self.car_y = random.randint(0, self.SCREEN_HEIGHT - self.car_height)
        self.destinations = self._create_destinations(5)
        self.obstacles = self._create_obstacles(10)
        self.game_over = False

        state = np.array([self.car_x, self.car_y], dtype=np.float32)
        return state

    def step(self, action):
        if action == 0 and self.car_x > 0:  # Left
            self.car_x -= self.car_speed
        elif action == 1 and self.car_x < self.SCREEN_WIDTH - self.car_width:  # Right
            self.car_x += self.car_speed
        elif action == 2 and self.car_y > 0:  # Up
            self.car_y -= self.car_speed
        elif action == 3 and self.car_y < self.SCREEN_HEIGHT - self.car_height:  # Down
            self.car_y += self.car_speed

        reward = 1  # Default reward for moving into the white area
        done = False
        
        if self._check_collision():
            reward -= 10
            self.times += 1
            print(f"{self.times}: -10")  # Penalty for hitting an obstacle

        for dest_x, dest_y in self.destinations:
            if self._is_car_parked(dest_x, dest_y):
                reward += 100
                self.times += 1
                print(f"{self.times}: +100")  # Reward for parking
                done = True

        state = np.array([self.car_x, self.car_y], dtype=np.float32)
        return state, reward, done, {}


    def render(self):
        if self.render_mode is None:
            return
        
        if self.screen is None:
            pygame.init()
            self.screen = pygame.display.set_mode((self.SCREEN_WIDTH, self.SCREEN_HEIGHT))
            self.clock = pygame.time.Clock()
        
        self.screen.fill(self.WHITE)
        self._draw_car()
        self._draw_obstacles()
        self._draw_destinations()
        
        pygame.display.flip()
        self.clock.tick(self.metadata["render_fps"])

    def close(self):
        if self.screen is not None:
            pygame.quit()
            self.screen = None
            self.clock = None

    def _create_obstacles(self, num_obstacles):
        obstacles = []
        for _ in range(num_obstacles):
            while True:
                obstacle_x = random.randint(0, self.SCREEN_WIDTH - 50)
                obstacle_y = random.randint(0, self.SCREEN_HEIGHT - 50)
                obstacle_rect = pygame.Rect(obstacle_x, obstacle_y, 50, 50)
                if not self._check_rect_collision(self.car_x, self.car_y, obstacle_rect) and not any(self._check_rect_collision(dest_x, dest_y, obstacle_rect) for dest_x, dest_y in self.destinations):
                    obstacles.append([obstacle_x, obstacle_y, 50, 50])
                    break
        return obstacles

    def _create_destinations(self, num_destinations):
        destinations = []
        for _ in range(num_destinations):
            while True:
                dest_x = random.randint(0, self.SCREEN_WIDTH - 50)
                dest_y = random.randint(0, self.SCREEN_HEIGHT - 50)
                dest_rect = pygame.Rect(dest_x - 25, dest_y - 25, 50, 50)
                if not self._check_rect_collision(self.car_x, self.car_y, dest_rect) and not any(self._check_rect_collision(dest_x, dest_y, pygame.Rect(obstacle[0], obstacle[1], obstacle[2], obstacle[3])) for obstacle in self.obstacles):
                    destinations.append((dest_x, dest_y))
                    break
        return destinations

    def _draw_car(self):
        pygame.draw.rect(self.screen, self.RED, [self.car_x, self.car_y, self.car_width, self.car_height])

    def _draw_obstacles(self):
        for obstacle in self.obstacles:
            pygame.draw.rect(self.screen, self.BLACK, obstacle)

    def _draw_destinations(self):
        for dest_x, dest_y in self.destinations:
            pygame.draw.rect(self.screen, self.GREEN, [dest_x - 25, dest_y - 25, 50, 50])

    def _check_collision(self):
        car_rect = pygame.Rect(self.car_x, self.car_y, self.car_width, self.car_height)
        for obstacle in self.obstacles:
            obstacle_rect = pygame.Rect(obstacle[0], obstacle[1], obstacle[2], obstacle[3])
            if car_rect.colliderect(obstacle_rect):
                return True
        return False

    def _is_car_parked(self, dest_x, dest_y):
        car_rect = pygame.Rect(self.car_x, self.car_y, self.car_width, self.car_height)
        dest_rect = pygame.Rect(dest_x - 25, dest_y - 25, 50, 50)
        intersection = car_rect.clip(dest_rect)
        if intersection.width * intersection.height >= 0.50 * self.car_width * self.car_height:
            return True
        return False

    def _check_rect_collision(self, x, y, rect):
        temp_rect = pygame.Rect(x, y, self.car_width, self.car_height)
        return temp_rect.colliderect(rect)
    


if __name__ == "__main__":
    env = ParkingEnv(render_mode="human")
    env.reset()
    running = True

    # Initialize pygame
    pygame.init()
    env.render()

    while running:
        for event in pygame.event.get():
            if event.type == pygame.QUIT:
                running = False
            elif event.type == pygame.KEYDOWN and event.key == pygame.K_ESCAPE:
                running = False
        
        action = env.action_space.sample()  # Random action
        _, _, done, _ = env.step(action)
        env.render()
    env.close()
# Out:
# 1: +100
# 2: -10
# 3: -10
# 4: -10
# 5: -10
# 6: -10
# 7: -10
# 8: -10
# 9: -10
# 10: -10
# 11: -10
# 12: +100
# 13: -10
# 14: -10
# 15: -10
# 16: -10
# 17: -10
# 18: -10
# 19: -10
# 20: -10
# 21: -10
# 22: -10
# 23: -10
# 24: -10
# 25: -10
# 26: -10
# 27: -10
# 28: -10
# 29: -10
# 30: -10
# 31: -10
# 32: -10
# 33: -10
# 34: -10
# 35: -10
# 36: -10
# 37: -10
# 38: -10
# 39: -10
# 40: -10
# 41: -10
# 42: -10
# 43: -10
# 44: -10
# 45: -10
# 46: -10
# 47: -10
# 48: -10
# 49: -10
# 50: -10
# 51: -10
# 52: -10
# 53: -10
# 54: -10
# 55: -10
# 56: -10
# 57: -10
# 58: -10
# 59: -10
# 60: -10
# 61: -10
# 62: -10
# 63: -10
# 64: -10
# 65: -10
# 66: -10
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[10], line 179
#     177     action = env.action_space.sample()  # Random action
#     178     _, _, done, _ = env.step(action)
# --> 179     env.render()
#     180 env.close()
#
# Cell In[10], line 96, in ParkingEnv.render(self)
#      93 self._draw_destinations()
#      95 pygame.display.flip()
# ---> 96 self.clock.tick(self.metadata["render_fps"])
#
# KeyboardInterrupt:

# %%
import pygame
import random
import numpy as np
from gymnasium import Env, spaces
from typing import Optional
from stable_baselines3 import PPO
import math

class ParkingEnv(Env):
    metadata = {"render_modes": ["human"], "render_fps": 240}

    def __init__(self, render_mode: Optional[str] = None):
        super().__init__()
        self.SCREEN_WIDTH = 400
        self.SCREEN_HEIGHT = 600
        self.DARK_GREEN = (0, 100, 0)
        self.BLACK = (0, 0, 0)
        self.RED = (255, 0, 0)
        
        self.road_width = 100
        self.car_size = 40
        self.car_speed = 50

        self.action_space = spaces.Discrete(4)  # [left, right, up, down]
        self.observation_space = spaces.Box(
            low=0,
            high=max(self.SCREEN_WIDTH, self.SCREEN_HEIGHT),
            shape=(2,),  # Car's x, y coordinates
            dtype=np.float32
        )
        
        self.render_mode = render_mode
        self.screen = None
        self.clock = None
        
        self.reset()
        self.times = 0
        self.human_feedback = 0

    def reset(self, seed=None, options=None):
        super().reset(seed=seed)
        self.car_x = self.SCREEN_WIDTH // 2 - self.car_size // 2
        self.car_y = self.SCREEN_HEIGHT - self.car_size - 10
        self.game_over = False

        state = np.array([self.car_x, self.car_y], dtype=np.float32)
        return state, {}  # Return state and an empty info dict

    def step(self, action):
        if action == 0:  # Left
            self.car_x -= self.car_speed
        elif action == 1:  # Right
            self.car_x += self.car_speed
        elif action == 2:  # Up
            self.car_y -= self.car_speed
        elif action == 3:  # Down
            self.car_y += self.car_speed

        # Ensure car stays within screen bounds
        self.car_x = max(0, min(self.car_x, self.SCREEN_WIDTH - self.car_size))
        self.car_y = max(0, min(self.car_y, self.SCREEN_HEIGHT - self.car_size))

        reward = self._calculate_reward()
        done = False
        
        if self.car_y <= 10 and abs(self.car_x - self.SCREEN_WIDTH // 2) < self.road_width // 2:
            reward += 100
            done = True
            self.times += 1
            print(f"{self.times}: Parked, reward = {reward}")

        state = np.array([self.car_x, self.car_y], dtype=np.float32)
        return state, reward + self.human_feedback, done, False, {}

    def _calculate_reward(self):
        if self._is_on_road():
            return 1  # Positive reward for staying on the road
        else:
            return -10  # Negative reward for being off the road

    def _is_on_road(self):
        center_x, center_y = self.SCREEN_WIDTH // 2, self.SCREEN_HEIGHT // 2
        car_center_x = self.car_x + self.car_size // 2
        car_center_y = self.car_y + self.car_size // 2
        
        # Calculate distance from car center to road center
        dx = abs(car_center_x - center_x)
        dy = abs(car_center_y - center_y)
        
        # Check if car is on the vertical part of the 8
        if dx < self.road_width // 2:
            return True
        
        # Check if car is on the curved part of the 8
        radius = self.SCREEN_HEIGHT // 4
        upper_center_y = center_y - radius
        lower_center_y = center_y + radius
        
        dist_upper = math.sqrt((car_center_x - center_x)**2 + (car_center_y - upper_center_y)**2)
        dist_lower = math.sqrt((car_center_x - center_x)**2 + (car_center_y - lower_center_y)**2)
        
        return min(dist_upper, dist_lower) < self.road_width // 2

    def render(self):
        if self.render_mode is None:
            return False
        
        if self.screen is None:
            pygame.init()
            self.screen = pygame.display.set_mode((self.SCREEN_WIDTH, self.SCREEN_HEIGHT))
            self.clock = pygame.time.Clock()
        
        for event in pygame.event.get():
            if event.type == pygame.QUIT:
                self.close()
                return True
            if event.type == pygame.KEYDOWN:
                if event.key == pygame.K_ESCAPE:
                    self.close()
                    return True
                elif event.key == pygame.K_UP:
                    self.human_feedback += 1
                    print("Positive feedback given")
                elif event.key == pygame.K_DOWN:
                    self.human_feedback -= 1
                    print("Negative feedback given")
        
        self.screen.fill(self.DARK_GREEN)
        self._draw_road()
        self._draw_car()
        
        pygame.display.flip()
        self.clock.tick(self.metadata["render_fps"])
        return False

    def close(self):
        if self.screen is not None:
            pygame.quit()
            self.screen = None
            self.clock = None

    def _draw_road(self):
        center_x, center_y = self.SCREEN_WIDTH // 2, self.SCREEN_HEIGHT // 2
        radius = self.SCREEN_HEIGHT // 4
        
        # Draw vertical part of 8
        pygame.draw.rect(self.screen, self.BLACK, [center_x - self.road_width // 2, 0, self.road_width, self.SCREEN_HEIGHT])
        
        # Draw upper circle of 8
        pygame.draw.circle(self.screen, self.BLACK, (center_x, center_y - radius), radius, self.road_width)
        
        # Draw lower circle of 8
        pygame.draw.circle(self.screen, self.BLACK, (center_x, center_y + radius), radius, self.road_width)

    def _draw_car(self):
        pygame.draw.rect(self.screen, self.RED, [self.car_x, self.car_y, self.car_size, self.car_size])

if __name__ == "__main__":
    from stable_baselines3 import PPO

    # Initialize the environment
    env = ParkingEnv(render_mode="human")

    # Define the PPO model
    model = PPO("MlpPolicy", env, verbose=1)

    # Train the model
    model.learn(total_timesteps=10000)  # Increased training time

    # Test the model
    num_runs = 10000
    for run in range(num_runs):
        obs, _ = env.reset()
        done = False
        total_reward = 0
        steps = 0
        
        while not done:
            action, _states = model.predict(obs)
            obs, reward, done, truncated, _info = env.step(action)
            total_reward += reward
            steps += 1
            should_exit = env.render()
            if should_exit:
                env.close()
                exit()
        
        print(f"Run {run + 1}/{num_runs} - Steps: {steps}, Total Reward: {total_reward}")
        
        # Small delay between runs to make it easier to see
        pygame.time.wait(1000)

    env.close()
# Out:
# Using cuda device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# 1: Parked, reward = 101
# 2: Parked, reward = 101
# 3: Parked, reward = 101
# 4: Parked, reward = 101
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 462       |
# |    ep_rew_mean     | -2.98e+03 |
# | time/              |           |
# |    fps             | 1609      |
# |    iterations      | 1         |
# |    time_elapsed    | 1         |
# |    total_timesteps | 2048      |
# ----------------------------------
# 5: Parked, reward = 101
# 6: Parked, reward = 101
# 7: Parked, reward = 101
# 8: Parked, reward = 101
# 9: Parked, reward = 101
# 10: Parked, reward = 101
# 11: Parked, reward = 101
# 12: Parked, reward = 101
# 13: Parked, reward = 101
# 14: Parked, reward = 101
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 266          |
# |    ep_rew_mean          | -1.71e+03    |
# | time/                   |              |
# |    fps                  | 1265         |
# |    iterations           | 2            |
# |    time_elapsed         | 3            |
# |    total_timesteps      | 4096         |
# | train/                  |              |
# |    approx_kl            | 0.016125754  |
# |    clip_fraction        | 0.144        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.38        |
# |    explained_variance   | -0.002049446 |
# |    learning_rate        | 0.0003       |
# |    loss                 | 5.35e+03     |
# |    n_updates            | 10           |
# |    policy_gradient_loss | -0.0208      |
# |    value_loss           | 1.22e+04     |
# ------------------------------------------
# 15: Parked, reward = 101
# 16: Parked, reward = 101
# 17: Parked, reward = 101
# 18: Parked, reward = 101
# 19: Parked, reward = 101
# 20: Parked, reward = 101
# 21: Parked, reward = 101
# 22: Parked, reward = 90
# 23: Parked, reward = 101
# 24: Parked, reward = 101
# 25: Parked, reward = 101
# 26: Parked, reward = 101
# 27: Parked, reward = 101
# 28: Parked, reward = 101
# 29: Parked, reward = 101
# 30: Parked, reward = 101
# 31: Parked, reward = 101
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 194          |
# |    ep_rew_mean          | -1.27e+03    |
# | time/                   |              |
# |    fps                  | 1169         |
# |    iterations           | 3            |
# |    time_elapsed         | 5            |
# |    total_timesteps      | 6144         |
# | train/                  |              |
# |    approx_kl            | 0.009171724  |
# |    clip_fraction        | 0.0574       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.36        |
# |    explained_variance   | -0.015546799 |
# |    learning_rate        | 0.0003       |
# |    loss                 | 6.42e+03     |
# |    n_updates            | 20           |
# |    policy_gradient_loss | -0.0108      |
# |    value_loss           | 1.29e+04     |
# ------------------------------------------
# 32: Parked, reward = 101
# 33: Parked, reward = 101
# 34: Parked, reward = 90
# 35: Parked, reward = 101
# 36: Parked, reward = 101
# 37: Parked, reward = 101
# 38: Parked, reward = 101
# 39: Parked, reward = 101
# 40: Parked, reward = 90
# 41: Parked, reward = 101
# 42: Parked, reward = 101
# 43: Parked, reward = 101
# 44: Parked, reward = 101
# 45: Parked, reward = 101
# 46: Parked, reward = 90
# 47: Parked, reward = 90
# 48: Parked, reward = 101
# 49: Parked, reward = 90
# 50: Parked, reward = 101
# 51: Parked, reward = 101
# 52: Parked, reward = 101
# 53: Parked, reward = 101
# 54: Parked, reward = 90
# 55: Parked, reward = 101
# 56: Parked, reward = 101
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 146           |
# |    ep_rew_mean          | -947          |
# | time/                   |               |
# |    fps                  | 901           |
# |    iterations           | 4             |
# |    time_elapsed         | 9             |
# |    total_timesteps      | 8192          |
# | train/                  |               |
# |    approx_kl            | 0.010981787   |
# |    clip_fraction        | 0.105         |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.33         |
# |    explained_variance   | 0.00058859587 |
# |    learning_rate        | 0.0003        |
# |    loss                 | 5.35e+03      |
# |    n_updates            | 30            |
# |    policy_gradient_loss | -0.012        |
# |    value_loss           | 1.04e+04      |
# -------------------------------------------
# 57: Parked, reward = 101
# 58: Parked, reward = 101
# 59: Parked, reward = 101
# 60: Parked, reward = 101
# 61: Parked, reward = 101
# 62: Parked, reward = 101
# 63: Parked, reward = 101
# 64: Parked, reward = 101
# 65: Parked, reward = 101
# 66: Parked, reward = 101
# 67: Parked, reward = 101
# 68: Parked, reward = 90
# 69: Parked, reward = 101
# 70: Parked, reward = 101
# 71: Parked, reward = 90
# 72: Parked, reward = 101
# 73: Parked, reward = 101
# 74: Parked, reward = 101
# 75: Parked, reward = 101
# 76: Parked, reward = 101
# 77: Parked, reward = 101
# 78: Parked, reward = 101
# 79: Parked, reward = 101
# 80: Parked, reward = 101
# 81: Parked, reward = 101
# 82: Parked, reward = 90
# 83: Parked, reward = 101
# 84: Parked, reward = 101
# 85: Parked, reward = 101
# 86: Parked, reward = 101
# 87: Parked, reward = 101
# 88: Parked, reward = 101
# 89: Parked, reward = 101
# 90: Parked, reward = 101
# 91: Parked, reward = 101
# 92: Parked, reward = 101
# 93: Parked, reward = 101
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 110           |
# |    ep_rew_mean          | -700          |
# | time/                   |               |
# |    fps                  | 791           |
# |    iterations           | 5             |
# |    time_elapsed         | 12            |
# |    total_timesteps      | 10240         |
# | train/                  |               |
# |    approx_kl            | 0.013830619   |
# |    clip_fraction        | 0.164         |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.28         |
# |    explained_variance   | -0.0014628172 |
# |    learning_rate        | 0.0003        |
# |    loss                 | 5.62e+03      |
# |    n_updates            | 40            |
# |    policy_gradient_loss | -0.0119       |
# |    value_loss           | 1.02e+04      |
# -------------------------------------------
# 94: Parked, reward = 101
# Run 1/10000 - Steps: 44, Total Reward: -318
# 95: Parked, reward = 90
# Run 2/10000 - Steps: 23, Total Reward: -130
# 96: Parked, reward = 101
# Run 3/10000 - Steps: 31, Total Reward: -89
# 97: Parked, reward = 101
# Run 4/10000 - Steps: 37, Total Reward: -160
# 98: Parked, reward = 101
# Run 5/10000 - Steps: 24, Total Reward: 69
# 99: Parked, reward = 90
# Run 6/10000 - Steps: 29, Total Reward: -102
# 100: Parked, reward = 90
# Run 7/10000 - Steps: 16, Total Reward: -5
# 101: Parked, reward = 101
# Run 8/10000 - Steps: 30, Total Reward: -178
# 102: Parked, reward = 101
# Run 9/10000 - Steps: 55, Total Reward: -428
# 103: Parked, reward = 90
# Run 10/10000 - Steps: 40, Total Reward: -124
# 104: Parked, reward = 101
# Run 11/10000 - Steps: 66, Total Reward: -417
# 105: Parked, reward = 90
# Run 12/10000 - Steps: 30, Total Reward: -156
# 106: Parked, reward = 90
# Run 13/10000 - Steps: 20, Total Reward: -89
# 107: Parked, reward = 101
# Run 14/10000 - Steps: 33, Total Reward: -54
# 108: Parked, reward = 90
# Run 15/10000 - Steps: 29, Total Reward: -25
# 109: Parked, reward = 101
# Run 16/10000 - Steps: 143, Total Reward: -1176
# 110: Parked, reward = 101
# Run 17/10000 - Steps: 58, Total Reward: -216
# 111: Parked, reward = 90
# Run 18/10000 - Steps: 18, Total Reward: -25
# 112: Parked, reward = 101
# Run 19/10000 - Steps: 50, Total Reward: -389
# 113: Parked, reward = 101
# Run 20/10000 - Steps: 16, Total Reward: 39
# 114: Parked, reward = 101
# Run 21/10000 - Steps: 14, Total Reward: 70
# 115: Parked, reward = 101
# Run 22/10000 - Steps: 72, Total Reward: -543
# 116: Parked, reward = 101
# Run 23/10000 - Steps: 33, Total Reward: -98
# 117: Parked, reward = 101
# Run 24/10000 - Steps: 47, Total Reward: -359
# 118: Parked, reward = 101
# Run 25/10000 - Steps: 42, Total Reward: -298
# 119: Parked, reward = 90
# Run 26/10000 - Steps: 35, Total Reward: -107
# 120: Parked, reward = 101
# Run 27/10000 - Steps: 18, Total Reward: 8
# 121: Parked, reward = 101
# Run 28/10000 - Steps: 33, Total Reward: -131
# 122: Parked, reward = 101
# Run 29/10000 - Steps: 30, Total Reward: -178
# 123: Parked, reward = 90
# Run 30/10000 - Steps: 30, Total Reward: -101
# 124: Parked, reward = 101
# Run 31/10000 - Steps: 90, Total Reward: -646
# 125: Parked, reward = 101
# Run 32/10000 - Steps: 45, Total Reward: -295
# 126: Parked, reward = 101
# Run 33/10000 - Steps: 25, Total Reward: -106
# 127: Parked, reward = 101
# Run 34/10000 - Steps: 36, Total Reward: -227
# 128: Parked, reward = 101
# Run 35/10000 - Steps: 23, Total Reward: -9
# 129: Parked, reward = 101
# Run 36/10000 - Steps: 81, Total Reward: -611
# 130: Parked, reward = 101
# Run 37/10000 - Steps: 30, Total Reward: -68
# 131: Parked, reward = 101
# Run 38/10000 - Steps: 37, Total Reward: -226
# 132: Parked, reward = 90
# Run 39/10000 - Steps: 24, Total Reward: -63
# 133: Parked, reward = 101
# Run 40/10000 - Steps: 76, Total Reward: -473
# 134: Parked, reward = 101
# Run 41/10000 - Steps: 50, Total Reward: -334
# 135: Parked, reward = 90
# Run 42/10000 - Steps: 16, Total Reward: -38
# 136: Parked, reward = 101
# Run 43/10000 - Steps: 19, Total Reward: -2
# 137: Parked, reward = 90
# Run 44/10000 - Steps: 24, Total Reward: 14
# 138: Parked, reward = 101
# Run 45/10000 - Steps: 22, Total Reward: -109
# 139: Parked, reward = 90
# Run 46/10000 - Steps: 22, Total Reward: -120
# 140: Parked, reward = 101
# Run 47/10000 - Steps: 51, Total Reward: -190
# 141: Parked, reward = 101
# Run 48/10000 - Steps: 55, Total Reward: -384
# 142: Parked, reward = 101
# Run 49/10000 - Steps: 48, Total Reward: -105
# 143: Parked, reward = 101
# Run 50/10000 - Steps: 41, Total Reward: -277
# 144: Parked, reward = 101
# Run 51/10000 - Steps: 31, Total Reward: -199
# 145: Parked, reward = 90
# Run 52/10000 - Steps: 14, Total Reward: 37
# 146: Parked, reward = 101
# Run 53/10000 - Steps: 46, Total Reward: -294
# 147: Parked, reward = 90
# Run 54/10000 - Steps: 26, Total Reward: -127
# 148: Parked, reward = 101
# Run 55/10000 - Steps: 73, Total Reward: -531
# 149: Parked, reward = 90
# Run 56/10000 - Steps: 32, Total Reward: -132
# 150: Parked, reward = 101
# Run 57/10000 - Steps: 36, Total Reward: -227
# 151: Parked, reward = 101
# Run 58/10000 - Steps: 78, Total Reward: -570
# 152: Parked, reward = 101
# Run 59/10000 - Steps: 51, Total Reward: -300
# 153: Parked, reward = 101
# Run 60/10000 - Steps: 30, Total Reward: -90
# 154: Parked, reward = 101
# Run 61/10000 - Steps: 51, Total Reward: -245
# 155: Parked, reward = 101
# Run 62/10000 - Steps: 42, Total Reward: -287
# 156: Parked, reward = 101
# Run 63/10000 - Steps: 26, Total Reward: -28
# 157: Parked, reward = 101
# Run 64/10000 - Steps: 29, Total Reward: -135
# 158: Parked, reward = 101
# Run 65/10000 - Steps: 81, Total Reward: -556
# 159: Parked, reward = 101
# Run 66/10000 - Steps: 33, Total Reward: -175
# 160: Parked, reward = 101
# Run 67/10000 - Steps: 51, Total Reward: -366
# 161: Parked, reward = 90
# Run 68/10000 - Steps: 26, Total Reward: -28
# 162: Parked, reward = 101
# Run 69/10000 - Steps: 44, Total Reward: -208
# 163: Parked, reward = 101
# Run 70/10000 - Steps: 19, Total Reward: 20
# 164: Parked, reward = 101
# Run 71/10000 - Steps: 26, Total Reward: 16
# 165: Parked, reward = 101
# Run 72/10000 - Steps: 36, Total Reward: -227
# 166: Parked, reward = 101
# Run 73/10000 - Steps: 53, Total Reward: -287
# 167: Parked, reward = 101
# Run 74/10000 - Steps: 89, Total Reward: -735
# 168: Parked, reward = 101
# Run 75/10000 - Steps: 35, Total Reward: -206
# 169: Parked, reward = 101
# Run 76/10000 - Steps: 99, Total Reward: -670
# 170: Parked, reward = 90
# Run 77/10000 - Steps: 23, Total Reward: -42
# 171: Parked, reward = 101
# Run 78/10000 - Steps: 42, Total Reward: -309
# 172: Parked, reward = 101
# Run 79/10000 - Steps: 42, Total Reward: -276
# 173: Parked, reward = 90
# Run 80/10000 - Steps: 22, Total Reward: 23
# 174: Parked, reward = 101
# Run 81/10000 - Steps: 57, Total Reward: -338
# 175: Parked, reward = 90
# Run 82/10000 - Steps: 22, Total Reward: -109
# 176: Parked, reward = 90
# Run 83/10000 - Steps: 26, Total Reward: -116
# 177: Parked, reward = 101
# Run 84/10000 - Steps: 42, Total Reward: -287
# 178: Parked, reward = 101
# Run 85/10000 - Steps: 37, Total Reward: -215
# 179: Parked, reward = 101
# Run 86/10000 - Steps: 29, Total Reward: -168
# 180: Parked, reward = 101
# Run 87/10000 - Steps: 66, Total Reward: -450
# 181: Parked, reward = 90
# Run 88/10000 - Steps: 30, Total Reward: -90
# 182: Parked, reward = 101
# Run 89/10000 - Steps: 37, Total Reward: -171
# 183: Parked, reward = 90
# Run 90/10000 - Steps: 21, Total Reward: -110
# 184: Parked, reward = 101
# Run 91/10000 - Steps: 48, Total Reward: -292
# 185: Parked, reward = 101
# Run 92/10000 - Steps: 92, Total Reward: -655
# 186: Parked, reward = 101
# Run 93/10000 - Steps: 36, Total Reward: -194
# 187: Parked, reward = 101
# Run 94/10000 - Steps: 56, Total Reward: -295
# 188: Parked, reward = 101
# Run 95/10000 - Steps: 57, Total Reward: -382
# 189: Parked, reward = 101
# Run 96/10000 - Steps: 72, Total Reward: -477
# 190: Parked, reward = 101
# Run 97/10000 - Steps: 58, Total Reward: -436
# 191: Parked, reward = 101
# Run 98/10000 - Steps: 29, Total Reward: -146
# 192: Parked, reward = 101
# Run 99/10000 - Steps: 33, Total Reward: -208
# 193: Parked, reward = 101
# Run 100/10000 - Steps: 109, Total Reward: -869
# 194: Parked, reward = 101
# Run 101/10000 - Steps: 104, Total Reward: -819
# 195: Parked, reward = 101
# Run 102/10000 - Steps: 43, Total Reward: -187
# 196: Parked, reward = 90
# Run 103/10000 - Steps: 16, Total Reward: -49
# 197: Parked, reward = 101
# Run 104/10000 - Steps: 53, Total Reward: -265
# 198: Parked, reward = 90
# Run 105/10000 - Steps: 21, Total Reward: -66
# 199: Parked, reward = 90
# Run 106/10000 - Steps: 20, Total Reward: -89
# 200: Parked, reward = 101
# Run 107/10000 - Steps: 26, Total Reward: -127
# 201: Parked, reward = 101
# Run 108/10000 - Steps: 33, Total Reward: -153
# 202: Parked, reward = 101
# Run 109/10000 - Steps: 48, Total Reward: -270
# 203: Parked, reward = 101
# Run 110/10000 - Steps: 32, Total Reward: -132
# 204: Parked, reward = 101
# Run 111/10000 - Steps: 44, Total Reward: -131
# 205: Parked, reward = 101
# Run 112/10000 - Steps: 45, Total Reward: -317
# 206: Parked, reward = 90
# Run 113/10000 - Steps: 16, Total Reward: -16
# 207: Parked, reward = 101
# Run 114/10000 - Steps: 29, Total Reward: -102
# 208: Parked, reward = 90
# Run 115/10000 - Steps: 28, Total Reward: -48
# 209: Parked, reward = 101
# Run 116/10000 - Steps: 33, Total Reward: -153
# 210: Parked, reward = 101
# Run 117/10000 - Steps: 46, Total Reward: -239
# 211: Parked, reward = 101
# Run 118/10000 - Steps: 28, Total Reward: -81
# 212: Parked, reward = 101
# Run 119/10000 - Steps: 31, Total Reward: -122
# 213: Parked, reward = 101
# Run 120/10000 - Steps: 42, Total Reward: -188
# 214: Parked, reward = 90
# Run 121/10000 - Steps: 24, Total Reward: -140
# 215: Parked, reward = 101
# Run 122/10000 - Steps: 57, Total Reward: -349
# 216: Parked, reward = 101
# Run 123/10000 - Steps: 37, Total Reward: -226
# 217: Parked, reward = 90
# Run 124/10000 - Steps: 16, Total Reward: -49
# 218: Parked, reward = 101
# Run 125/10000 - Steps: 47, Total Reward: -348
# 219: Parked, reward = 101
# Run 126/10000 - Steps: 21, Total Reward: 11
# 220: Parked, reward = 101
# Run 127/10000 - Steps: 24, Total Reward: 36
# 221: Parked, reward = 90
# Run 128/10000 - Steps: 63, Total Reward: -409
# 222: Parked, reward = 90
# Run 129/10000 - Steps: 24, Total Reward: -129
# 223: Parked, reward = 101
# Run 130/10000 - Steps: 24, Total Reward: -41
# 224: Parked, reward = 101
# Run 131/10000 - Steps: 24, Total Reward: -63
# 225: Parked, reward = 90
# Run 132/10000 - Steps: 24, Total Reward: -107
# 226: Parked, reward = 101
# Run 133/10000 - Steps: 38, Total Reward: -203
# 227: Parked, reward = 101
# Run 134/10000 - Steps: 31, Total Reward: -56
# 228: Parked, reward = 101
# Run 135/10000 - Steps: 26, Total Reward: -127
# 229: Parked, reward = 101
# Run 136/10000 - Steps: 35, Total Reward: -184
# 230: Parked, reward = 101
# Run 137/10000 - Steps: 19, Total Reward: -13
# 231: Parked, reward = 101
# Run 138/10000 - Steps: 27, Total Reward: -71
# 232: Parked, reward = 101
# Run 139/10000 - Steps: 35, Total Reward: -173
# 233: Parked, reward = 101
# Run 140/10000 - Steps: 41, Total Reward: -90
# 234: Parked, reward = 101
# Run 141/10000 - Steps: 74, Total Reward: -497
# 235: Parked, reward = 101
# Run 142/10000 - Steps: 21, Total Reward: -55
# 236: Parked, reward = 101
# Run 143/10000 - Steps: 38, Total Reward: -247
# 237: Parked, reward = 101
# Run 144/10000 - Steps: 17, Total Reward: 7
# 238: Parked, reward = 90
# Run 145/10000 - Steps: 16, Total Reward: -5
# 239: Parked, reward = 101
# Run 146/10000 - Steps: 21, Total Reward: -33
# 240: Parked, reward = 101
# Run 147/10000 - Steps: 45, Total Reward: -207
# 241: Parked, reward = 90
# Run 148/10000 - Steps: 32, Total Reward: -187
# 242: Parked, reward = 101
# Run 149/10000 - Steps: 74, Total Reward: -618
# 243: Parked, reward = 101
# Run 150/10000 - Steps: 20, Total Reward: 10
# 244: Parked, reward = 101
# Run 151/10000 - Steps: 92, Total Reward: -567
# 245: Parked, reward = 90
# Run 152/10000 - Steps: 28, Total Reward: -147
# 246: Parked, reward = 101
# Run 153/10000 - Steps: 63, Total Reward: -420
# 247: Parked, reward = 90
# Run 154/10000 - Steps: 32, Total Reward: -176
# 248: Parked, reward = 90
# Run 155/10000 - Steps: 27, Total Reward: -104
# 249: Parked, reward = 101
# Run 156/10000 - Steps: 47, Total Reward: -282
# 250: Parked, reward = 101
# Run 157/10000 - Steps: 21, Total Reward: 55
# 251: Parked, reward = 90
# Run 158/10000 - Steps: 17, Total Reward: -37
# 252: Parked, reward = 101
# Run 159/10000 - Steps: 40, Total Reward: -168
# 253: Parked, reward = 101
# Run 160/10000 - Steps: 25, Total Reward: -29
# 254: Parked, reward = 101
# Run 161/10000 - Steps: 39, Total Reward: -268
# 255: Parked, reward = 90
# Run 162/10000 - Steps: 25, Total Reward: -106
# 256: Parked, reward = 90
# Run 163/10000 - Steps: 23, Total Reward: -42
# 257: Parked, reward = 101
# Run 164/10000 - Steps: 29, Total Reward: -69
# 258: Parked, reward = 101
# Run 165/10000 - Steps: 29, Total Reward: -168
# 259: Parked, reward = 101
# Run 166/10000 - Steps: 14, Total Reward: 103
# 260: Parked, reward = 101
# Run 167/10000 - Steps: 45, Total Reward: -196
# 261: Parked, reward = 101
# Run 168/10000 - Steps: 116, Total Reward: -895
# 262: Parked, reward = 101
# Run 169/10000 - Steps: 38, Total Reward: -236
# 263: Parked, reward = 90
# Run 170/10000 - Steps: 23, Total Reward: -119
# 264: Parked, reward = 101
# Run 171/10000 - Steps: 21, Total Reward: 11
# 265: Parked, reward = 101
# Run 172/10000 - Steps: 23, Total Reward: -64
# 266: Parked, reward = 101
# Run 173/10000 - Steps: 87, Total Reward: -715
# 267: Parked, reward = 101
# Run 174/10000 - Steps: 54, Total Reward: -429
# 268: Parked, reward = 90
# Run 175/10000 - Steps: 39, Total Reward: -158
# 269: Parked, reward = 101
# Run 176/10000 - Steps: 18, Total Reward: -47
# 270: Parked, reward = 90
# Run 177/10000 - Steps: 22, Total Reward: -21
# 271: Parked, reward = 101
# Run 178/10000 - Steps: 34, Total Reward: -218
# 272: Parked, reward = 101
# Run 179/10000 - Steps: 51, Total Reward: -399
# 273: Parked, reward = 90
# Run 180/10000 - Steps: 37, Total Reward: -127
# 274: Parked, reward = 101
# Run 181/10000 - Steps: 34, Total Reward: -229
# 275: Parked, reward = 101
# Run 182/10000 - Steps: 97, Total Reward: -716
# 276: Parked, reward = 101
# Run 183/10000 - Steps: 19, Total Reward: -2
# 277: Parked, reward = 90
# Run 184/10000 - Steps: 26, Total Reward: -116
# 278: Parked, reward = 101
# Run 185/10000 - Steps: 35, Total Reward: -217
# 279: Parked, reward = 101
# Run 186/10000 - Steps: 30, Total Reward: -167
# 280: Parked, reward = 90
# Run 187/10000 - Steps: 21, Total Reward: -33
# 281: Parked, reward = 101
# Run 188/10000 - Steps: 77, Total Reward: -461
# 282: Parked, reward = 101
# Run 189/10000 - Steps: 94, Total Reward: -719
# 283: Parked, reward = 90
# Run 190/10000 - Steps: 23, Total Reward: -86
# 284: Parked, reward = 90
# Run 191/10000 - Steps: 21, Total Reward: -99
# 285: Parked, reward = 101
# Run 192/10000 - Steps: 29, Total Reward: -113
# 286: Parked, reward = 101
# Run 193/10000 - Steps: 38, Total Reward: -159
# 287: Parked, reward = 90
# Run 194/10000 - Steps: 22, Total Reward: -109
# 288: Parked, reward = 90
# Run 195/10000 - Steps: 63, Total Reward: -200
# 289: Parked, reward = 101
# Run 196/10000 - Steps: 17, Total Reward: -15
# 290: Parked, reward = 101
# Run 197/10000 - Steps: 125, Total Reward: -831
# 291: Parked, reward = 101
# Run 198/10000 - Steps: 44, Total Reward: -175
# 292: Parked, reward = 90
# Run 199/10000 - Steps: 30, Total Reward: -156
# 293: Parked, reward = 101
# Run 200/10000 - Steps: 42, Total Reward: -199
# 294: Parked, reward = 101
# Run 201/10000 - Steps: 94, Total Reward: -730
# 295: Parked, reward = 90
# Run 202/10000 - Steps: 21, Total Reward: 33
# 296: Parked, reward = 101
# Run 203/10000 - Steps: 73, Total Reward: -586
# 297: Parked, reward = 101
# Run 204/10000 - Steps: 39, Total Reward: -202
# 298: Parked, reward = 101
# Run 205/10000 - Steps: 64, Total Reward: -485
# 299: Parked, reward = 90
# Run 206/10000 - Steps: 22, Total Reward: 1
# 300: Parked, reward = 101
# Run 207/10000 - Steps: 46, Total Reward: -338
# 301: Parked, reward = 90
# Run 208/10000 - Steps: 38, Total Reward: -192
# 302: Parked, reward = 101
# Run 209/10000 - Steps: 13, Total Reward: 25
# 303: Parked, reward = 101
# Run 210/10000 - Steps: 36, Total Reward: -238
# 304: Parked, reward = 90
# Run 211/10000 - Steps: 22, Total Reward: -32
# 305: Parked, reward = 101
# Run 212/10000 - Steps: 46, Total Reward: -316
# 306: Parked, reward = 101
# Run 213/10000 - Steps: 27, Total Reward: -82
# 307: Parked, reward = 90
# Run 214/10000 - Steps: 26, Total Reward: -116
# 308: Parked, reward = 101
# Run 215/10000 - Steps: 40, Total Reward: -135
# 309: Parked, reward = 90
# Run 216/10000 - Steps: 33, Total Reward: -131
# 310: Parked, reward = 90
# Run 217/10000 - Steps: 19, Total Reward: -79
# 311: Parked, reward = 90
# Run 218/10000 - Steps: 33, Total Reward: -208
# 312: Parked, reward = 101
# Run 219/10000 - Steps: 55, Total Reward: -439
# 313: Parked, reward = 101
# Run 220/10000 - Steps: 21, Total Reward: 11
# 314: Parked, reward = 90
# Run 221/10000 - Steps: 23, Total Reward: -119
# 315: Parked, reward = 101
# Run 222/10000 - Steps: 27, Total Reward: -49
# 316: Parked, reward = 101
# Run 223/10000 - Steps: 83, Total Reward: -587
# 317: Parked, reward = 101
# Run 224/10000 - Steps: 42, Total Reward: -210
# 318: Parked, reward = 101
# Run 225/10000 - Steps: 44, Total Reward: -307
# 319: Parked, reward = 90
# Run 226/10000 - Steps: 23, Total Reward: -20
# 320: Parked, reward = 101
# Run 227/10000 - Steps: 34, Total Reward: -163
# 321: Parked, reward = 101
# Run 228/10000 - Steps: 50, Total Reward: -345
# 322: Parked, reward = 90
# Run 229/10000 - Steps: 20, Total Reward: -45
# 323: Parked, reward = 101
# Run 230/10000 - Steps: 30, Total Reward: -35
# 324: Parked, reward = 101
# Run 231/10000 - Steps: 87, Total Reward: -572
# 325: Parked, reward = 101
# Run 232/10000 - Steps: 43, Total Reward: -242
# 326: Parked, reward = 90
# Run 233/10000 - Steps: 19, Total Reward: -24
# 327: Parked, reward = 90
# Run 234/10000 - Steps: 37, Total Reward: -105
# 328: Parked, reward = 101
# Run 235/10000 - Steps: 21, Total Reward: -66
# 329: Parked, reward = 90
# Run 236/10000 - Steps: 22, Total Reward: -54
# 330: Parked, reward = 101
# Run 237/10000 - Steps: 58, Total Reward: -337
# 331: Parked, reward = 101
# Run 238/10000 - Steps: 44, Total Reward: -153
# 332: Parked, reward = 90
# Run 239/10000 - Steps: 20, Total Reward: -12
# 333: Parked, reward = 90
# Run 240/10000 - Steps: 19, Total Reward: -13
# 334: Parked, reward = 90
# Run 241/10000 - Steps: 58, Total Reward: -238
# 335: Parked, reward = 90
# Run 242/10000 - Steps: 24, Total Reward: -107
# 336: Parked, reward = 101
# Run 243/10000 - Steps: 67, Total Reward: -427
# 337: Parked, reward = 101
# Run 244/10000 - Steps: 49, Total Reward: -225
# 338: Parked, reward = 101
# Run 245/10000 - Steps: 39, Total Reward: -279
# 339: Parked, reward = 101
# Run 246/10000 - Steps: 15, Total Reward: 49
# 340: Parked, reward = 101
# Run 247/10000 - Steps: 38, Total Reward: -126
# 341: Parked, reward = 101
# Run 248/10000 - Steps: 15, Total Reward: 71
# 342: Parked, reward = 101
# Run 249/10000 - Steps: 29, Total Reward: -135
# 343: Parked, reward = 90
# Run 250/10000 - Steps: 65, Total Reward: -341
# 344: Parked, reward = 90
# Run 251/10000 - Steps: 30, Total Reward: -90
# 345: Parked, reward = 90
# Run 252/10000 - Steps: 36, Total Reward: -227
# 346: Parked, reward = 101
# Run 253/10000 - Steps: 27, Total Reward: -82
# 347: Parked, reward = 101
# Run 254/10000 - Steps: 32, Total Reward: -209
# 348: Parked, reward = 101
# Run 255/10000 - Steps: 41, Total Reward: -288
# 349: Parked, reward = 90
# Run 256/10000 - Steps: 41, Total Reward: -233
# 350: Parked, reward = 90
# Run 257/10000 - Steps: 27, Total Reward: -159
# 351: Parked, reward = 101
# Run 258/10000 - Steps: 45, Total Reward: -152
# 352: Parked, reward = 101
# Run 259/10000 - Steps: 19, Total Reward: -13
# 353: Parked, reward = 90
# Run 260/10000 - Steps: 26, Total Reward: -160
# 354: Parked, reward = 101
# Run 261/10000 - Steps: 49, Total Reward: -269
# 355: Parked, reward = 101
# Run 262/10000 - Steps: 27, Total Reward: -126
# 356: Parked, reward = 101
# Run 263/10000 - Steps: 62, Total Reward: -509
# 357: Parked, reward = 90
# Run 264/10000 - Steps: 40, Total Reward: -146
# 358: Parked, reward = 101
# Run 265/10000 - Steps: 33, Total Reward: -153
# 359: Parked, reward = 101
# Run 266/10000 - Steps: 15, Total Reward: 71
# 360: Parked, reward = 101
# Run 267/10000 - Steps: 32, Total Reward: -198
# 361: Parked, reward = 101
# Run 268/10000 - Steps: 22, Total Reward: 12
# 362: Parked, reward = 90
# Run 269/10000 - Steps: 36, Total Reward: -106
# 363: Parked, reward = 101
# Run 270/10000 - Steps: 23, Total Reward: -9
# 364: Parked, reward = 101
# Run 271/10000 - Steps: 60, Total Reward: -401
# 365: Parked, reward = 101
# Run 272/10000 - Steps: 20, Total Reward: -67
# 366: Parked, reward = 101
# Run 273/10000 - Steps: 27, Total Reward: -16
# 367: Parked, reward = 101
# Run 274/10000 - Steps: 41, Total Reward: -299
# 368: Parked, reward = 101
# Run 275/10000 - Steps: 37, Total Reward: -215
# 369: Parked, reward = 101
# Run 276/10000 - Steps: 49, Total Reward: -269
# 370: Parked, reward = 101
# Run 277/10000 - Steps: 26, Total Reward: -50
# 371: Parked, reward = 101
# Run 278/10000 - Steps: 73, Total Reward: -421
# 372: Parked, reward = 101
# Run 279/10000 - Steps: 79, Total Reward: -635
# 373: Parked, reward = 101
# Run 280/10000 - Steps: 21, Total Reward: -22
# 374: Parked, reward = 101
# Run 281/10000 - Steps: 30, Total Reward: -13
# 375: Parked, reward = 90
# Run 282/10000 - Steps: 24, Total Reward: -107
# 376: Parked, reward = 90
# Run 283/10000 - Steps: 25, Total Reward: -29
# 377: Parked, reward = 101
# Run 284/10000 - Steps: 46, Total Reward: -316
# 378: Parked, reward = 101
# Run 285/10000 - Steps: 50, Total Reward: -389
# 379: Parked, reward = 101
# Run 286/10000 - Steps: 27, Total Reward: 28
# 380: Parked, reward = 101
# Run 287/10000 - Steps: 23, Total Reward: -75
# 381: Parked, reward = 101
# Run 288/10000 - Steps: 42, Total Reward: -177
# 382: Parked, reward = 101
# Run 289/10000 - Steps: 55, Total Reward: -373
# 383: Parked, reward = 90
# Run 290/10000 - Steps: 32, Total Reward: -110
# 384: Parked, reward = 101
# Run 291/10000 - Steps: 37, Total Reward: -160
# 385: Parked, reward = 101
# Run 292/10000 - Steps: 42, Total Reward: -133
# 386: Parked, reward = 101
# Run 293/10000 - Steps: 49, Total Reward: -324
# 387: Parked, reward = 101
# Run 294/10000 - Steps: 34, Total Reward: -97
# 388: Parked, reward = 101
# Run 295/10000 - Steps: 48, Total Reward: -215
# 389: Parked, reward = 90
# Run 296/10000 - Steps: 18, Total Reward: -36
# 390: Parked, reward = 101
# Run 297/10000 - Steps: 63, Total Reward: -431
# 391: Parked, reward = 101
# Run 298/10000 - Steps: 70, Total Reward: -446
# 392: Parked, reward = 101
# Run 299/10000 - Steps: 19, Total Reward: -79
# 393: Parked, reward = 90
# Run 300/10000 - Steps: 24, Total Reward: -30
# 394: Parked, reward = 90
# Run 301/10000 - Steps: 21, Total Reward: -22
# 395: Parked, reward = 101
# Run 302/10000 - Steps: 23, Total Reward: -9
# 396: Parked, reward = 101
# Run 303/10000 - Steps: 53, Total Reward: -375
# 397: Parked, reward = 90
# Run 304/10000 - Steps: 41, Total Reward: -277
# 398: Parked, reward = 90
# Run 305/10000 - Steps: 17, Total Reward: 29
# 399: Parked, reward = 101
# Run 306/10000 - Steps: 28, Total Reward: -114
# 400: Parked, reward = 101
# Run 307/10000 - Steps: 52, Total Reward: -167
# 401: Parked, reward = 90
# Run 308/10000 - Steps: 27, Total Reward: -60
# 402: Parked, reward = 101
# Run 309/10000 - Steps: 207, Total Reward: -1574
# 403: Parked, reward = 90
# Run 310/10000 - Steps: 40, Total Reward: -135
# 404: Parked, reward = 101
# Run 311/10000 - Steps: 74, Total Reward: -530
# 405: Parked, reward = 90
# Run 312/10000 - Steps: 58, Total Reward: -172
# 406: Parked, reward = 90
# Run 313/10000 - Steps: 37, Total Reward: -127
# 407: Parked, reward = 90
# Run 314/10000 - Steps: 30, Total Reward: -123
# 408: Parked, reward = 90
# Run 315/10000 - Steps: 26, Total Reward: -105
# 409: Parked, reward = 101
# Run 316/10000 - Steps: 32, Total Reward: -66
# 410: Parked, reward = 90
# Run 317/10000 - Steps: 27, Total Reward: -38
# 411: Parked, reward = 90
# Run 318/10000 - Steps: 23, Total Reward: -86
# 412: Parked, reward = 90
# Run 319/10000 - Steps: 22, Total Reward: -65
# 413: Parked, reward = 101
# Run 320/10000 - Steps: 86, Total Reward: -518
# 414: Parked, reward = 101
# Run 321/10000 - Steps: 55, Total Reward: -329
# 415: Parked, reward = 101
# Run 322/10000 - Steps: 151, Total Reward: -1388
# 416: Parked, reward = 101
# Run 323/10000 - Steps: 17, Total Reward: 84
# 417: Parked, reward = 101
# Run 324/10000 - Steps: 33, Total Reward: -109
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[4], line 183
#     181 total_reward += reward
#     182 steps += 1
# --> 183 should_exit = env.render()
#     184 if should_exit:
#     185     env.close()
#
# Cell In[4], line 133, in ParkingEnv.render(self)
#     130 self._draw_car()
#     132 pygame.display.flip()
# --> 133 self.clock.tick(self.metadata["render_fps"])
#     134 return False
#
# KeyboardInterrupt:
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
